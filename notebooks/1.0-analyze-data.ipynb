# %% [markdown]
# # Analyze data

# %% [markdown]
# # 1. Imports

# %% [markdown]
# ## 1.1 Packages

# %%
import os
import pandas as pd

from summarytools import dfSummary

# %% [markdown]
# ## 1.2 Options

# %%
path_data = "../data/01_raw"

# %% [markdown]
# ## 1.3 Dataset

# %%
df = pd.read_parquet(os.path.join(path_data, "fremotor1prem0304.parquet"))

# %% [markdown]
# # 2. Analyze data

# %%
df.head()
# Out:
#          IDpol    Year  DrivAge DrivGender MaritalStatus  BonusMalus  \
# 0  1000111.100  2003.0     44.0          F    Cohabiting        50.0
# 1  1000113.100  2003.0     26.0          F    Cohabiting        85.0
# 3  1000113.100  2003.0     27.0          F    Cohabiting       106.0
# 4  1000173.100  2003.0     52.0          M    Cohabiting        50.0
# 5  1000173.101  2003.0     52.0          M    Cohabiting        50.0
#
#    LicenceNb      PayFreq           JobCode  VehAge  ... PremFire PremAcc1  \
# 0        3.0  Half-yearly  Private employee    10.0  ...      0.0      0.0
# 1        2.0       Annual             Other     8.0  ...      0.0      0.0
# 3        2.0  Half-yearly             Other     6.0  ...      0.0      0.0
# 4        2.0  Half-yearly  Private employee     2.0  ...      5.0      0.0
# 5        2.0  Half-yearly  Private employee     1.0  ...      8.0      0.0
#
#   PremAcc2 PremLegal PremTPLM PremTPLV PremServ PremTheft PremTot  \
# 0      0.0       6.0     69.1      4.0     50.0       0.0   144.1
# 1      0.0       7.0    139.3      7.0     46.0       0.0   215.3
# 3      0.0      17.0    453.6     24.0     57.0       0.0   611.6
# 4     47.0       9.0    111.2      5.0     48.0      50.0   415.2
# 5      0.0      11.0    132.8      7.0     48.0      90.0   487.8
#
#    IDpol_corrected
# 0      1000111.100
# 1      1000113.100
# 3      1000113.100
# 4      1000173.100
# 5      1000173.101
#
# [5 rows x 31 columns]

# %%
# EDA using jupyter summarytools

dfSummary(df)
# Out:
# <style type="text/css">
# #T_e1b28 thead>tr>th {
#   text-align: left;
# }
# #T_e1b28_row0_col0, #T_e1b28_row1_col0, #T_e1b28_row2_col0, #T_e1b28_row3_col0, #T_e1b28_row4_col0, #T_e1b28_row5_col0, #T_e1b28_row6_col0, #T_e1b28_row7_col0, #T_e1b28_row8_col0, #T_e1b28_row9_col0, #T_e1b28_row10_col0, #T_e1b28_row11_col0, #T_e1b28_row12_col0, #T_e1b28_row13_col0, #T_e1b28_row14_col0, #T_e1b28_row15_col0, #T_e1b28_row16_col0, #T_e1b28_row17_col0, #T_e1b28_row18_col0, #T_e1b28_row19_col0, #T_e1b28_row20_col0, #T_e1b28_row21_col0, #T_e1b28_row22_col0, #T_e1b28_row23_col0, #T_e1b28_row24_col0, #T_e1b28_row25_col0, #T_e1b28_row26_col0, #T_e1b28_row27_col0, #T_e1b28_row28_col0, #T_e1b28_row29_col0, #T_e1b28_row30_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_e1b28_row0_col1, #T_e1b28_row1_col1, #T_e1b28_row2_col1, #T_e1b28_row3_col1, #T_e1b28_row4_col1, #T_e1b28_row5_col1, #T_e1b28_row6_col1, #T_e1b28_row7_col1, #T_e1b28_row8_col1, #T_e1b28_row9_col1, #T_e1b28_row10_col1, #T_e1b28_row11_col1, #T_e1b28_row12_col1, #T_e1b28_row13_col1, #T_e1b28_row14_col1, #T_e1b28_row15_col1, #T_e1b28_row16_col1, #T_e1b28_row17_col1, #T_e1b28_row18_col1, #T_e1b28_row19_col1, #T_e1b28_row20_col1, #T_e1b28_row21_col1, #T_e1b28_row22_col1, #T_e1b28_row23_col1, #T_e1b28_row24_col1, #T_e1b28_row25_col1, #T_e1b28_row26_col1, #T_e1b28_row27_col1, #T_e1b28_row28_col1, #T_e1b28_row29_col1, #T_e1b28_row30_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_e1b28_row0_col2, #T_e1b28_row1_col2, #T_e1b28_row2_col2, #T_e1b28_row3_col2, #T_e1b28_row4_col2, #T_e1b28_row5_col2, #T_e1b28_row6_col2, #T_e1b28_row7_col2, #T_e1b28_row8_col2, #T_e1b28_row9_col2, #T_e1b28_row10_col2, #T_e1b28_row11_col2, #T_e1b28_row12_col2, #T_e1b28_row13_col2, #T_e1b28_row14_col2, #T_e1b28_row15_col2, #T_e1b28_row16_col2, #T_e1b28_row17_col2, #T_e1b28_row18_col2, #T_e1b28_row19_col2, #T_e1b28_row20_col2, #T_e1b28_row21_col2, #T_e1b28_row22_col2, #T_e1b28_row23_col2, #T_e1b28_row24_col2, #T_e1b28_row25_col2, #T_e1b28_row26_col2, #T_e1b28_row27_col2, #T_e1b28_row28_col2, #T_e1b28_row29_col2, #T_e1b28_row30_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_e1b28_row0_col3, #T_e1b28_row1_col3, #T_e1b28_row2_col3, #T_e1b28_row3_col3, #T_e1b28_row4_col3, #T_e1b28_row5_col3, #T_e1b28_row6_col3, #T_e1b28_row7_col3, #T_e1b28_row8_col3, #T_e1b28_row9_col3, #T_e1b28_row10_col3, #T_e1b28_row11_col3, #T_e1b28_row12_col3, #T_e1b28_row13_col3, #T_e1b28_row14_col3, #T_e1b28_row15_col3, #T_e1b28_row16_col3, #T_e1b28_row17_col3, #T_e1b28_row18_col3, #T_e1b28_row19_col3, #T_e1b28_row20_col3, #T_e1b28_row21_col3, #T_e1b28_row22_col3, #T_e1b28_row23_col3, #T_e1b28_row24_col3, #T_e1b28_row25_col3, #T_e1b28_row26_col3, #T_e1b28_row27_col3, #T_e1b28_row28_col3, #T_e1b28_row29_col3, #T_e1b28_row30_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_e1b28_row0_col4, #T_e1b28_row1_col4, #T_e1b28_row2_col4, #T_e1b28_row3_col4, #T_e1b28_row4_col4, #T_e1b28_row5_col4, #T_e1b28_row6_col4, #T_e1b28_row7_col4, #T_e1b28_row8_col4, #T_e1b28_row9_col4, #T_e1b28_row10_col4, #T_e1b28_row11_col4, #T_e1b28_row12_col4, #T_e1b28_row13_col4, #T_e1b28_row14_col4, #T_e1b28_row15_col4, #T_e1b28_row16_col4, #T_e1b28_row17_col4, #T_e1b28_row18_col4, #T_e1b28_row19_col4, #T_e1b28_row20_col4, #T_e1b28_row21_col4, #T_e1b28_row22_col4, #T_e1b28_row23_col4, #T_e1b28_row24_col4, #T_e1b28_row25_col4, #T_e1b28_row26_col4, #T_e1b28_row27_col4, #T_e1b28_row28_col4, #T_e1b28_row29_col4, #T_e1b28_row30_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_e1b28_row0_col5, #T_e1b28_row1_col5, #T_e1b28_row2_col5, #T_e1b28_row3_col5, #T_e1b28_row4_col5, #T_e1b28_row5_col5, #T_e1b28_row6_col5, #T_e1b28_row7_col5, #T_e1b28_row8_col5, #T_e1b28_row9_col5, #T_e1b28_row10_col5, #T_e1b28_row11_col5, #T_e1b28_row12_col5, #T_e1b28_row13_col5, #T_e1b28_row14_col5, #T_e1b28_row15_col5, #T_e1b28_row16_col5, #T_e1b28_row17_col5, #T_e1b28_row18_col5, #T_e1b28_row19_col5, #T_e1b28_row20_col5, #T_e1b28_row21_col5, #T_e1b28_row22_col5, #T_e1b28_row23_col5, #T_e1b28_row24_col5, #T_e1b28_row25_col5, #T_e1b28_row26_col5, #T_e1b28_row27_col5, #T_e1b28_row28_col5, #T_e1b28_row29_col5, #T_e1b28_row30_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_e1b28">
#   <caption><strong>Data Frame Summary</strong><br>df<br>Dimensions: 27,808 x 31<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_e1b28_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_e1b28_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_e1b28_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_e1b28_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_e1b28_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_e1b28_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e1b28_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e1b28_row0_col1" class="data row0 col1" ><strong>IDpol</strong><br>[object]</td>
#       <td id="T_e1b28_row0_col2" class="data row0 col2" >1. 90119367.101<br>2. 90138155.101<br>3. 90106223.100<br>4. 90115981.101<br>5. 90104426.103<br>6. 90185775.100<br>7. 90112503.102<br>8. 90159192.100<br>9. 90162989.100<br>10. 90110428.100<br>11. other</td>
#       <td id="T_e1b28_row0_col3" class="data row0 col3" >3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>3 (0.0%)<br>27,778 (99.9%)</td>
#       <td id="T_e1b28_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_e1b28_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e1b28_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e1b28_row1_col1" class="data row1 col1" ><strong>Year</strong><br>[float64]</td>
#       <td id="T_e1b28_row1_col2" class="data row1 col2" >1. 2003.0<br>2. 2004.0</td>
#       <td id="T_e1b28_row1_col3" class="data row1 col3" >25,747 (92.6%)<br>2,061 (7.4%)</td>
#       <td id="T_e1b28_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_e1b28_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e1b28_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_e1b28_row2_col1" class="data row2 col1" ><strong>DrivAge</strong><br>[float64]</td>
#       <td id="T_e1b28_row2_col2" class="data row2 col2" >Mean (sd) : 39.8 (11.9)<br>min < med < max:<br>18.0 < 38.0 < 97.0<br>IQR (CV) : 16.0 (3.3)</td>
#       <td id="T_e1b28_row2_col3" class="data row2 col3" >72 distinct values</td>
#       <td id="T_e1b28_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_e1b28_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e1b28_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_e1b28_row3_col1" class="data row3 col1" ><strong>DrivGender</strong><br>[category]</td>
#       <td id="T_e1b28_row3_col2" class="data row3 col2" >1. M<br>2. F</td>
#       <td id="T_e1b28_row3_col3" class="data row3 col3" >18,242 (65.6%)<br>9,566 (34.4%)</td>
#       <td id="T_e1b28_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_e1b28_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_e1b28_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_e1b28_row4_col1" class="data row4 col1" ><strong>MaritalStatus</strong><br>[category]</td>
#       <td id="T_e1b28_row4_col2" class="data row4 col2" >1. nan<br>2. Cohabiting<br>3. Married<br>4. Single<br>5. Widowed<br>6. Divorced</td
